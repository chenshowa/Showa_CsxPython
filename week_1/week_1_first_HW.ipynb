# %%
import pandas as pd

# %%
df = pd.read_csv(r'C:\Users\chenhur\Documents\GitHub\Showa_CsxPython\week_1\Ntu_Orders.csv')

# %%
df.shape
# Out:
# (2268348, 27)

# %%
df.shape[0]
# Out:
# 2268348

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2268348 entries, 0 to 2268347
# Data columns (total 27 columns):
# ﻿SalesOrderSlaveId             int64
# DateId                         int64
# MemberId                       object
# TradesOrderSlaveId             int64
# ShopId                         int64
# SalePageId                     int64
# TradesOrderGroupCode           object
# TrackSourceTypeDef             object
# TrackChannelTypeDef            object
# TrackDeviceTypeDef             object
# LevelOneCategoryName           object
# LevelTwoCategoryName           object
# LevelThreeCategoryName         object
# LevelFourCategoryName          object
# IsMajor                        bool
# IsGift                         bool
# Quantity                       int64
# UnitPrice                      float64
# PromotionDiscount              float64
# EcouponDiscount                float64
# SalesOrderSlaveTotalPayment    float64
# SalesOrderSlaveDateTime        object
# ...

# %%
df.head(15)
# Out:
#        ﻿SalesOrderSlaveId    DateId                              MemberId  \
# Index
# 0                26914456  20170103  48D5DE26-236E-4854-8474-B0DCEAFF4F42
# 1                26914457  20170103  48D5DE26-236E-4854-8474-B0DCEAFF4F42
# 2                26767644  20170101  C8B989DB-05F9-42D3-BD4F-E203482C5E58
# 3                26780512  20170101  C39E36F7-5091-48DA-BE8F-8CE043E009EE
# 4                26823950  20170102  7D87099A-B49C-4136-A8E9-F76BB5588B19
# 5                26881155  20170103  2ED6E54C-A7B0-447F-B3C7-8B0CA4536E54
# 6                26928963  20170104  6B11D879-C56E-4057-A6A0-45C30732F542
# 7                26942457  20170104  249FEB46-134C-4DE3-902D-73D289D130DB
# 8                26945149  20170104  54B80CB7-78BA-49D7-9850-0A61A9B67E03
# 9                26914458  20170103  48D5DE26-236E-4854-8474-B0DCEAFF4F42
# 10               26914459  20170103  48D5DE26-236E-4854-8474-B0DCEAFF4F42
# 11               26978857  20170105  C474F574-761B-4D9A-B20F-4261F85EC1D4
# ...

# %%
df.loc[0:15, ['LevelOneCategoryName', 'LevelTwoCategoryName', 'LevelThreeCategoryName', 'LevelFourCategoryName', 'IsMajor', 'Quantity',"IsGift","UnitPrice","PromotionDiscount" ]]
# Out:
#       LevelOneCategoryName LevelTwoCategoryName LevelThreeCategoryName  \
# Index
# 0                   服裝、內睡衣                   女裝                     上衣
# 1                   服裝、內睡衣                   女裝                     上衣
# 2                   服裝、內睡衣                   女裝                     上衣
# 3                   服裝、內睡衣                   女裝                     上衣
# 4                   服裝、內睡衣                   女裝                     上衣
# 5                   服裝、內睡衣                   女裝                     上衣
# 6                   服裝、內睡衣                   女裝                     上衣
# 7                   服裝、內睡衣                   女裝                     上衣
# 8                   服裝、內睡衣                   女裝                     上衣
# 9                   服裝、內睡衣                   女裝                     上衣
# 10                  服裝、內睡衣                   女裝                     上衣
# 11                  服裝、內睡衣                   女裝                     上衣
# ...

# %%
df['One'] = 1

# %%
df['Index'] = range(0, df.shape[0]) 
df = df.set_index('Index')

# %%
day_start = df.loc[df.shape[0]-1, 'new_DateId'] - pd.DateOffset(days=29) # get start date
day_start
# Out:
# Timestamp('2017-11-21 00:00:00')

# %%
df.tail(3)
# Out:
#          ﻿SalesOrderSlaveId    DateId                              MemberId  \
# Index
# 2268345            50057718  20171220  CEC073AD-FED6-4382-A408-56527B10DE4E
# 2268346            50057719  20171220  CEC073AD-FED6-4382-A408-56527B10DE4E
# 2268347            50058976  20171220  F135AC00-E702-47F1-B496-8EDCBE62EBBD
#
#          TradesOrderSlaveId  ShopId  SalePageId  \
# Index
# 2268345            50121525    1317        9125
# 2268346            50121526    1317        8602
# 2268347            50122780    1317       10114
#
#                                       TradesOrderGroupCode TrackSourceTypeDef  \
# Index
# 2268345  b'\xdd\xda\xe9\xbb\x12#\xe3\xca7\x0e\xb07\xff#...                Web
# 2268346  b'\xdd\xda\xe9\xbb\x12#\xe3\xca7\x0e\xb07\xff#...                Web
# 2268347  b'\xf4\n\x14\xdc\x85n\x17JY\x14\xb3\x99v\x15\x...                Web
#
#         TrackChannelTypeDef TrackDeviceTypeDef     ...     PromotionDiscount  \
# ...

# %%
type(pd.DateOffset(30))
# Out:
# pandas.tseries.offsets.DateOffset

# %%
data = df.groupby(by='new_DateId')['Quantity'].sum()
data.head(10)
# Out:
# new_DateId
# 2017-01-01    3823
# 2017-01-02    5105
# 2017-01-03    3623
# 2017-01-04    2889
# 2017-01-05    2843
# 2017-01-06    2391
# 2017-01-07    2641
# 2017-01-08    2335
# 2017-01-09    2119
# 2017-01-10    2470
# Name: Quantity, dtype: int64

# %%
df.loc[0:5, ['LevelFourCategoryName', 'Quantity']]
# Out:
#       LevelFourCategoryName  Quantity
# Index
# 0                     T恤/帽T         1
# 1                     T恤/帽T         1
# 2                        洋裝         1
# 3                     成套衣褲組         1
# 4                        洋裝         1
# 5                     T恤/帽T         1

# %%
df.loc[0:5, ['new_DateId', 'Quantity']]
# Out:
#       new_DateId  Quantity
# Index
# 0     2017-01-03         1
# 1     2017-01-03         1
# 2     2017-01-01         1
# 3     2017-01-01         1
# 4     2017-01-02         1
# 5     2017-01-03         1

# %% [markdown]
# ## 每一天的商品交易總量

# %%
# %matplotlib inline
data.plot()  # 會默認第一個變數是 X 軸，第二個變數是 Y 軸。

# %% [markdown]
# ## 每一個會員在2017的交易量

# %%
Member_data = df.groupby(by='MemberId')['Quantity'].sum()
#Member_data.head(10)
Member_data.plot()

#Member_data.shape()

# %% [markdown]
# ## 取貨地點統計

# %%
import matplotlib.pyplot as plt

# %%
ShippingProfileType_data = df.groupby(by='ShippingProfileTypeDef')['Quantity'].sum()

ShippingProfileType_data.plot(kind='bar')

plt.show()

# %%
ShippingProfileType_data = df.groupby(by='ShippingProfileTypeDef')['One'].sum()

ShippingProfileType_data.plot(kind='bar')
plt.show()

# %% [markdown]
# ## 消費者端常用裝置

# %%
ShippingProfileType_data = df.groupby(by='TrackSourceTypeDef')['One'].sum()
ShippingProfileType_data.plot(kind='bar')
plt.show()

# %%
#byCol = 'LevelFourCategoryName'
#data = df.groupby(by=byCol)['Quantity'].sum()
